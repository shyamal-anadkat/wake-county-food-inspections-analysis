# %%
import numpy as np
import pandas as pd
from pathlib import Path
import requests
import json

# %%
# Url
endpoint = 'https://opendata.arcgis.com/datasets/693811eb361f4da286891eca1fae5943_0.geojson'

# Fetch the data
r = requests.get(url = endpoint)
rows = []
data = r.json()['features']
for d in data:
    rows.append(d['properties'])
df = pd.DataFrame(rows)
print(df.shape)
df.head()
# Out:
# (1349, 25)
#    OBJECTID                              GlobalID              CreationDate  \
# 0    529022  c330e7f9-d92e-494e-ac86-5a7668506b52  2020-02-18T20:14:01.341Z
# 1    529023  842c43c3-9411-4d1e-b4d0-c6f8de560892  2020-02-18T20:14:01.341Z
# 2    529035  aa32c9dd-318e-4a7c-906c-3fceec8a0f7e  2020-02-18T17:58:16.023Z
# 3    529038  2ef2112c-3cad-4ddc-a0ed-c9ca3a609288  2020-02-18T17:58:16.023Z
# 4    529046  ac21533f-7ece-4adc-ac07-48a506f27c4f  2020-02-18T17:58:16.023Z
#
#       Creator                  EditDate      Editor case_number  \
# 0  RaleighGIS  2020-02-18T20:14:01.341Z  RaleighGIS   P20009234
# 1  RaleighGIS  2020-02-18T20:14:01.341Z  RaleighGIS   P20009234
# 2  RaleighGIS  2020-02-18T17:58:16.023Z  RaleighGIS   P20009235
# 3  RaleighGIS  2020-02-18T17:58:16.023Z  RaleighGIS
# 4  RaleighGIS  2020-02-18T17:58:16.023Z  RaleighGIS
#
#        crime_category crime_code                crime_description  ...  \
# 0             LARCENY        35D      Larceny/Theft from Building  ...
# 1               FRAUD        56B      Fraud/Credit Card-ATM Fraud  ...
# 2  ALL OTHER OFFENSES        80A     All Other/All Other Offenses  ...
# 3       MISCELLANEOUS        81F  Miscellaneous/Mental Commitment  ...
# 4       MISCELLANEOUS        81C     Miscellaneous/Found Property  ...
#
#           reported_date reported_year reported_month reported_day  \
# 0  2020-02-17T05:15:00Z          2020              2           17
# 1  2020-02-17T05:15:00Z          2020              2           17
# 2  2020-02-17T05:48:00Z          2020              2           17
# 3  2020-02-17T06:35:00Z          2020              2           17
# 4  2020-02-17T08:11:00Z          2020              2           17
#
#   reported_hour reported_dayofwk   latitude  longitude  agency  \
# 0             0           Monday  35.874504 -78.622925     RPD
# 1             0           Monday  35.874504 -78.622925     RPD
# 2             0           Monday  35.778107 -78.634200     RPD
# 3             1           Monday   0.000000   0.000000     RPD
# 4             3           Monday   0.000000   0.000000     RPD
#
#                updated_date
# 0  2020-02-17T22:02:04.983Z
# 1  2020-02-17T22:02:04.983Z
# 2  2020-02-17T16:38:21.820Z
# 3  2020-02-17T16:22:49.540Z
# 4  2020-02-17T16:39:12.820Z
#
# [5 rows x 25 columns]
